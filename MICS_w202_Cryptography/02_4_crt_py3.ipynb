# %% [markdown]
# ### UC Berkeley, MICS, W202-Cryptography
# ### Week 02  Breakout 4
# ### Chinese Remainder Theorem (CRT)

# %% [markdown]
# Chinese Remainder Theorem (CRT) - solves a system of simultaneous linear congruences.  See Hoffstein 2.8
#
# From Sun Tzu Suan Ching (Master Sun's Mathematical Manual) circa 300 AD, volume 3, problem 26:
#
# * We have a number of things, but we do not know exactly how many.
# * If we count them by threes, we have two left over.
# * If we count them by fives, we have three left over.
# * If we count them by sevens, we have two left over.
# * How many things are there?
#
# The above orignal example of the Chinese Remainder Theorem details a system of 3 simultanenous linear congruences. We can solve them manually by hand by writing a system of equations (see Hoffstein 2.8 for worked examples)
#
# The Chinese Remainder Theorem is said to have originated with the ancient Chinese armies.  Warriers were told to line up in 3 different configurations and the remainders were noted and used to quickly count large armies.
#
# Below we will use brute force code below to find solutions to systems of simultaneous linear congruences.
#
# The Chinese Remainder Theorem has a special representation or notation that we saw in our lecture material. This CRT notation helps us to manually understand and work mathematical problems, such as finding square roots in modulo.  Of special importance to cryptography is using the CRT notation to express numbers in modulo n where n = pq in terms of modulo p and modulo q.  Below we will see code to enumerate a modulus period using CRT notation.
#
# Note that each line in the CRT notation is a system of linear congruences.

# %% [markdown]
# ### Using the Chinese Remainder Theorem CRT to solve a system of linear congruences by brute force

# %%
from sage.all import *

# %%
def my_solve_crt(congruence_list):
    "Given a list containing a system of linear congruences (residue, modulus) solve the system using brute force"
    
    print ("\nCongruences:")
    for (residue, modulus) in congruence_list:
        print ("    x congruent " + str(residue) + " (mod " + str(modulus) + ")")
    
    modulus_product = 1
    
    start_value = 0
    
    for (residue, modulus) in congruence_list:
        modulus_product *= modulus
        if residue > start_value:
            start_value = residue
        
    
    print ("\nstart value:", start_value)
    print ("stop value :", modulus_product, "\n(inclusive)\n")
    
    if modulus_product > 200:
        print ("won't print the list since modulus product is > 200\n")
    
    found = False
    solution = -1
    
    for i in range(start_value, modulus_product):
        for (residue, modulus) in congruence_list:
            if (i % modulus) == residue:
                found = True
                solution = i
            else:
                found = False
                if modulus_product < 200:
                    print ("    ", i, "is NOT a solution")
                break
        if found:
            solution = i
            break
            
    if found:
        print ("\n***", solution, "is the solution ***")
        for (residue, modulus) in congruence_list:
            print ("    " + str(solution) + " (mod " + str(modulus) + ") = " + str(residue))
    else:
        print ("\n*** NO SOLUTION ***")

# %%
# Solve Sun Tzu Suan Ching (Master Sun's Mathematical Manual) circa 300 AD, volume 3, problem 26:

# We have a number of things, but we do not know exactly how many.
# If we count them by threes, we have two left over.
# If we count them by fives, we have three left over.
# If we count them by sevens, we have two left over.
# How many things are there?

my_solve_crt([(2,3),(3,5),(2,7)])
# Out:
# Congruences:
#     x congruent 2 (mod 3)
#     x congruent 3 (mod 5)
#     x congruent 2 (mod 7)
#
# start value: 3
# stop value : 105
# (inclusive)
#
#      3 is NOT a solution
#      4 is NOT a solution
#      5 is NOT a solution
#      6 is NOT a solution
#      7 is NOT a solution
#      8 is NOT a solution
#      9 is NOT a solution
#      10 is NOT a solution
#      11 is NOT a solution
#      12 is NOT a solution
#      13 is NOT a solution
#      14 is NOT a solution
#      15 is NOT a solution
#      16 is NOT a solution
#      17 is NOT a solution
#      18 is NOT a solution
#      19 is NOT a solution
#      20 is NOT a solution
#      21 is NOT a solution
#      22 is NOT a solution
#
# *** 23 is the solution ***
#     23 (mod 3) = 2
#     23 (mod 5) = 3
#     23 (mod 7) = 2

# %%
# The Chinese Remainder Theorem is said to have originated with the ancient Chinese armies
# as a quick way to count large numbers of warriers

# assume warriers were told to line up:
# first into columns of 11 yielding 5 remainders
# then columns of 13 yielding 8 remainders
# then columns of 17 yielding 14 remainders

# as you can see below there are 1204 warriers that could be quickly counted 
# just by counting the remainders

my_solve_crt([(5,11),(8,13),(14,17)])
# Out:
# Congruences:
#     x congruent 5 (mod 11)
#     x congruent 8 (mod 13)
#     x congruent 14 (mod 17)
#
# start value: 14
# stop value : 2431
# (inclusive)
#
# won't print the list since modulus product is > 200
#
#
# *** 1204 is the solution ***
#     1204 (mod 11) = 5
#     1204 (mod 13) = 8
#     1204 (mod 17) = 14

# %%
my_solve_crt([(1,5),(7,9)])
# Out:
# Congruences:
#     x congruent 1 (mod 5)
#     x congruent 7 (mod 9)
#
# start value: 7
# stop value : 45
# (inclusive)
#
#      7 is NOT a solution
#      8 is NOT a solution
#      9 is NOT a solution
#      10 is NOT a solution
#      11 is NOT a solution
#      12 is NOT a solution
#      13 is NOT a solution
#      14 is NOT a solution
#      15 is NOT a solution
#
# *** 16 is the solution ***
#     16 (mod 5) = 1
#     16 (mod 9) = 7

# %%
my_solve_crt([(1,4),(2,7),(8,11),(11,13)])
# Out:
# Congruences:
#     x congruent 1 (mod 4)
#     x congruent 2 (mod 7)
#     x congruent 8 (mod 11)
#     x congruent 11 (mod 13)
#
# start value: 11
# stop value : 4004
# (inclusive)
#
# won't print the list since modulus product is > 200
#
#
# *** 1493 is the solution ***
#     1493 (mod 4) = 1
#     1493 (mod 7) = 2
#     1493 (mod 11) = 8
#     1493 (mod 13) = 11

# %%
my_solve_crt([(3,5),(2,11),(18,27)])
# Out:
# Congruences:
#     x congruent 3 (mod 5)
#     x congruent 2 (mod 11)
#     x congruent 18 (mod 27)
#
# start value: 18
# stop value : 1485
# (inclusive)
#
# won't print the list since modulus product is > 200
#
#
# *** 288 is the solution ***
#     288 (mod 5) = 3
#     288 (mod 11) = 2
#     288 (mod 27) = 18

# %%
my_solve_crt([(3,7),(2,11)])
# Out:
# Congruences:
#     x congruent 3 (mod 7)
#     x congruent 2 (mod 11)
#
# start value: 3
# stop value : 77
# (inclusive)
#
#      3 is NOT a solution
#      4 is NOT a solution
#      5 is NOT a solution
#      6 is NOT a solution
#      7 is NOT a solution
#      8 is NOT a solution
#      9 is NOT a solution
#      10 is NOT a solution
#      11 is NOT a solution
#      12 is NOT a solution
#      13 is NOT a solution
#      14 is NOT a solution
#      15 is NOT a solution
#      16 is NOT a solution
#      17 is NOT a solution
#      18 is NOT a solution
#      19 is NOT a solution
#      20 is NOT a solution
#      21 is NOT a solution
#      22 is NOT a solution
#      23 is NOT a solution
#
# *** 24 is the solution ***
#     24 (mod 7) = 3
#     24 (mod 11) = 2

# %% [markdown]
# ### Chinese Remainder Theorem CRT Notation
#
# Note that each line in the CRT notation is a system of linear congruences.

# %%
def my_crt_notation(n):
    "given an integer n, factor it into p and q, and write 1 period [0,(n-1)] inclusive using Chinese Remainder Theorem CRT Notation"
    
    if n <= 1:
        print ("must be > 1")
        return
    
    f = factor(n)
    
    if len(f) != 2:
        print ("not a product of two primes")
        return
        
    if f[0][1] != 1:
        print ("not a product of two primes")
        return
        
    q = f[0][0]
    p = f[1][0]
    
    
    print ("\nn = ", n)
    print ("\nq = ", q)
    print ("p = ", p,  "\n")
    
    for i in range(0,n):
        
        if (i % q) == 0 or (i % p) == 0:
            s = "  a zero tells us it's NOT relatively prime"
        else:
            s = ""
            
        print (str(i) + " mod " + str(n) + " = < " + str(i % q) + " mod " + str(q) + " , " + str(i % p) + " mod " + str(p) + " > " + s)

# %%
my_crt_notation(21)
# Out:
# n =  21
#
# q =  3
# p =  7
#
# 0 mod 21 = < 0 mod 3 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 1 mod 21 = < 1 mod 3 , 1 mod 7 >
# 2 mod 21 = < 2 mod 3 , 2 mod 7 >
# 3 mod 21 = < 0 mod 3 , 3 mod 7 >   a zero tells us it's NOT relatively prime
# 4 mod 21 = < 1 mod 3 , 4 mod 7 >
# 5 mod 21 = < 2 mod 3 , 5 mod 7 >
# 6 mod 21 = < 0 mod 3 , 6 mod 7 >   a zero tells us it's NOT relatively prime
# 7 mod 21 = < 1 mod 3 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 8 mod 21 = < 2 mod 3 , 1 mod 7 >
# 9 mod 21 = < 0 mod 3 , 2 mod 7 >   a zero tells us it's NOT relatively prime
# 10 mod 21 = < 1 mod 3 , 3 mod 7 >
# 11 mod 21 = < 2 mod 3 , 4 mod 7 >
# 12 mod 21 = < 0 mod 3 , 5 mod 7 >   a zero tells us it's NOT relatively prime
# 13 mod 21 = < 1 mod 3 , 6 mod 7 >
# 14 mod 21 = < 2 mod 3 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 15 mod 21 = < 0 mod 3 , 1 mod 7 >   a zero tells us it's NOT relatively prime
# 16 mod 21 = < 1 mod 3 , 2 mod 7 >
# 17 mod 21 = < 2 mod 3 , 3 mod 7 >
# 18 mod 21 = < 0 mod 3 , 4 mod 7 >   a zero tells us it's NOT relatively prime
# 19 mod 21 = < 1 mod 3 , 5 mod 7 >
# 20 mod 21 = < 2 mod 3 , 6 mod 7 >

# %%
my_crt_notation(15)
# Out:
# n =  15
#
# q =  3
# p =  5
#
# 0 mod 15 = < 0 mod 3 , 0 mod 5 >   a zero tells us it's NOT relatively prime
# 1 mod 15 = < 1 mod 3 , 1 mod 5 >
# 2 mod 15 = < 2 mod 3 , 2 mod 5 >
# 3 mod 15 = < 0 mod 3 , 3 mod 5 >   a zero tells us it's NOT relatively prime
# 4 mod 15 = < 1 mod 3 , 4 mod 5 >
# 5 mod 15 = < 2 mod 3 , 0 mod 5 >   a zero tells us it's NOT relatively prime
# 6 mod 15 = < 0 mod 3 , 1 mod 5 >   a zero tells us it's NOT relatively prime
# 7 mod 15 = < 1 mod 3 , 2 mod 5 >
# 8 mod 15 = < 2 mod 3 , 3 mod 5 >
# 9 mod 15 = < 0 mod 3 , 4 mod 5 >   a zero tells us it's NOT relatively prime
# 10 mod 15 = < 1 mod 3 , 0 mod 5 >   a zero tells us it's NOT relatively prime
# 11 mod 15 = < 2 mod 3 , 1 mod 5 >
# 12 mod 15 = < 0 mod 3 , 2 mod 5 >   a zero tells us it's NOT relatively prime
# 13 mod 15 = < 1 mod 3 , 3 mod 5 >
# 14 mod 15 = < 2 mod 3 , 4 mod 5 >

# %%
my_crt_notation(35)
# Out:
# n =  35
#
# q =  5
# p =  7
#
# 0 mod 35 = < 0 mod 5 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 1 mod 35 = < 1 mod 5 , 1 mod 7 >
# 2 mod 35 = < 2 mod 5 , 2 mod 7 >
# 3 mod 35 = < 3 mod 5 , 3 mod 7 >
# 4 mod 35 = < 4 mod 5 , 4 mod 7 >
# 5 mod 35 = < 0 mod 5 , 5 mod 7 >   a zero tells us it's NOT relatively prime
# 6 mod 35 = < 1 mod 5 , 6 mod 7 >
# 7 mod 35 = < 2 mod 5 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 8 mod 35 = < 3 mod 5 , 1 mod 7 >
# 9 mod 35 = < 4 mod 5 , 2 mod 7 >
# 10 mod 35 = < 0 mod 5 , 3 mod 7 >   a zero tells us it's NOT relatively prime
# 11 mod 35 = < 1 mod 5 , 4 mod 7 >
# 12 mod 35 = < 2 mod 5 , 5 mod 7 >
# 13 mod 35 = < 3 mod 5 , 6 mod 7 >
# 14 mod 35 = < 4 mod 5 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 15 mod 35 = < 0 mod 5 , 1 mod 7 >   a zero tells us it's NOT relatively prime
# 16 mod 35 = < 1 mod 5 , 2 mod 7 >
# 17 mod 35 = < 2 mod 5 , 3 mod 7 >
# 18 mod 35 = < 3 mod 5 , 4 mod 7 >
# 19 mod 35 = < 4 mod 5 , 5 mod 7 >
# 20 mod 35 = < 0 mod 5 , 6 mod 7 >   a zero tells us it's NOT relatively prime
# 21 mod 35 = < 1 mod 5 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 22 mod 35 = < 2 mod 5 , 1 mod 7 >
# 23 mod 35 = < 3 mod 5 , 2 mod 7 >
# 24 mod 35 = < 4 mod 5 , 3 mod 7 >
# 25 mod 35 = < 0 mod 5 , 4 mod 7 >   a zero tells us it's NOT relatively prime
# 26 mod 35 = < 1 mod 5 , 5 mod 7 >
# 27 mod 35 = < 2 mod 5 , 6 mod 7 >
# 28 mod 35 = < 3 mod 5 , 0 mod 7 >   a zero tells us it's NOT relatively prime
# 29 mod 35 = < 4 mod 5 , 1 mod 7 >
# 30 mod 35 = < 0 mod 5 , 2 mod 7 >   a zero tells us it's NOT relatively prime
# 31 mod 35 = < 1 mod 5 , 3 mod 7 >
# 32 mod 35 = < 2 mod 5 , 4 mod 7 >
# 33 mod 35 = < 3 mod 5 , 5 mod 7 >
# 34 mod 35 = < 4 mod 5 , 6 mod 7 >

# %%
my_crt_notation(77)
# Out:
# n =  77
#
# q =  7
# p =  11
#
# 0 mod 77 = < 0 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 1 mod 77 = < 1 mod 7 , 1 mod 11 >
# 2 mod 77 = < 2 mod 7 , 2 mod 11 >
# 3 mod 77 = < 3 mod 7 , 3 mod 11 >
# 4 mod 77 = < 4 mod 7 , 4 mod 11 >
# 5 mod 77 = < 5 mod 7 , 5 mod 11 >
# 6 mod 77 = < 6 mod 7 , 6 mod 11 >
# 7 mod 77 = < 0 mod 7 , 7 mod 11 >   a zero tells us it's NOT relatively prime
# 8 mod 77 = < 1 mod 7 , 8 mod 11 >
# 9 mod 77 = < 2 mod 7 , 9 mod 11 >
# 10 mod 77 = < 3 mod 7 , 10 mod 11 >
# 11 mod 77 = < 4 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 12 mod 77 = < 5 mod 7 , 1 mod 11 >
# 13 mod 77 = < 6 mod 7 , 2 mod 11 >
# 14 mod 77 = < 0 mod 7 , 3 mod 11 >   a zero tells us it's NOT relatively prime
# 15 mod 77 = < 1 mod 7 , 4 mod 11 >
# 16 mod 77 = < 2 mod 7 , 5 mod 11 >
# 17 mod 77 = < 3 mod 7 , 6 mod 11 >
# 18 mod 77 = < 4 mod 7 , 7 mod 11 >
# 19 mod 77 = < 5 mod 7 , 8 mod 11 >
# 20 mod 77 = < 6 mod 7 , 9 mod 11 >
# 21 mod 77 = < 0 mod 7 , 10 mod 11 >   a zero tells us it's NOT relatively prime
# 22 mod 77 = < 1 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 23 mod 77 = < 2 mod 7 , 1 mod 11 >
# 24 mod 77 = < 3 mod 7 , 2 mod 11 >
# 25 mod 77 = < 4 mod 7 , 3 mod 11 >
# 26 mod 77 = < 5 mod 7 , 4 mod 11 >
# 27 mod 77 = < 6 mod 7 , 5 mod 11 >
# 28 mod 77 = < 0 mod 7 , 6 mod 11 >   a zero tells us it's NOT relatively prime
# 29 mod 77 = < 1 mod 7 , 7 mod 11 >
# 30 mod 77 = < 2 mod 7 , 8 mod 11 >
# 31 mod 77 = < 3 mod 7 , 9 mod 11 >
# 32 mod 77 = < 4 mod 7 , 10 mod 11 >
# 33 mod 77 = < 5 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 34 mod 77 = < 6 mod 7 , 1 mod 11 >
# 35 mod 77 = < 0 mod 7 , 2 mod 11 >   a zero tells us it's NOT relatively prime
# 36 mod 77 = < 1 mod 7 , 3 mod 11 >
# 37 mod 77 = < 2 mod 7 , 4 mod 11 >
# 38 mod 77 = < 3 mod 7 , 5 mod 11 >
# 39 mod 77 = < 4 mod 7 , 6 mod 11 >
# 40 mod 77 = < 5 mod 7 , 7 mod 11 >
# 41 mod 77 = < 6 mod 7 , 8 mod 11 >
# 42 mod 77 = < 0 mod 7 , 9 mod 11 >   a zero tells us it's NOT relatively prime
# 43 mod 77 = < 1 mod 7 , 10 mod 11 >
# 44 mod 77 = < 2 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 45 mod 77 = < 3 mod 7 , 1 mod 11 >
# 46 mod 77 = < 4 mod 7 , 2 mod 11 >
# 47 mod 77 = < 5 mod 7 , 3 mod 11 >
# 48 mod 77 = < 6 mod 7 , 4 mod 11 >
# 49 mod 77 = < 0 mod 7 , 5 mod 11 >   a zero tells us it's NOT relatively prime
# 50 mod 77 = < 1 mod 7 , 6 mod 11 >
# 51 mod 77 = < 2 mod 7 , 7 mod 11 >
# 52 mod 77 = < 3 mod 7 , 8 mod 11 >
# 53 mod 77 = < 4 mod 7 , 9 mod 11 >
# 54 mod 77 = < 5 mod 7 , 10 mod 11 >
# 55 mod 77 = < 6 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 56 mod 77 = < 0 mod 7 , 1 mod 11 >   a zero tells us it's NOT relatively prime
# 57 mod 77 = < 1 mod 7 , 2 mod 11 >
# 58 mod 77 = < 2 mod 7 , 3 mod 11 >
# 59 mod 77 = < 3 mod 7 , 4 mod 11 >
# 60 mod 77 = < 4 mod 7 , 5 mod 11 >
# 61 mod 77 = < 5 mod 7 , 6 mod 11 >
# 62 mod 77 = < 6 mod 7 , 7 mod 11 >
# 63 mod 77 = < 0 mod 7 , 8 mod 11 >   a zero tells us it's NOT relatively prime
# 64 mod 77 = < 1 mod 7 , 9 mod 11 >
# 65 mod 77 = < 2 mod 7 , 10 mod 11 >
# 66 mod 77 = < 3 mod 7 , 0 mod 11 >   a zero tells us it's NOT relatively prime
# 67 mod 77 = < 4 mod 7 , 1 mod 11 >
# 68 mod 77 = < 5 mod 7 , 2 mod 11 >
# 69 mod 77 = < 6 mod 7 , 3 mod 11 >
# 70 mod 77 = < 0 mod 7 , 4 mod 11 >   a zero tells us it's NOT relatively prime
# 71 mod 77 = < 1 mod 7 , 5 mod 11 >
# 72 mod 77 = < 2 mod 7 , 6 mod 11 >
# 73 mod 77 = < 3 mod 7 , 7 mod 11 >
# 74 mod 77 = < 4 mod 7 , 8 mod 11 >
# 75 mod 77 = < 5 mod 7 , 9 mod 11 >
# 76 mod 77 = < 6 mod 7 , 10 mod 11 >

# %%
my_crt_notation(781)
# Out:
# n =  781
#
# q =  11
# p =  71
#
# 0 mod 781 = < 0 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 1 mod 781 = < 1 mod 11 , 1 mod 71 >
# 2 mod 781 = < 2 mod 11 , 2 mod 71 >
# 3 mod 781 = < 3 mod 11 , 3 mod 71 >
# 4 mod 781 = < 4 mod 11 , 4 mod 71 >
# 5 mod 781 = < 5 mod 11 , 5 mod 71 >
# 6 mod 781 = < 6 mod 11 , 6 mod 71 >
# 7 mod 781 = < 7 mod 11 , 7 mod 71 >
# 8 mod 781 = < 8 mod 11 , 8 mod 71 >
# 9 mod 781 = < 9 mod 11 , 9 mod 71 >
# 10 mod 781 = < 10 mod 11 , 10 mod 71 >
# 11 mod 781 = < 0 mod 11 , 11 mod 71 >   a zero tells us it's NOT relatively prime
# 12 mod 781 = < 1 mod 11 , 12 mod 71 >
# 13 mod 781 = < 2 mod 11 , 13 mod 71 >
# 14 mod 781 = < 3 mod 11 , 14 mod 71 >
# 15 mod 781 = < 4 mod 11 , 15 mod 71 >
# 16 mod 781 = < 5 mod 11 , 16 mod 71 >
# 17 mod 781 = < 6 mod 11 , 17 mod 71 >
# 18 mod 781 = < 7 mod 11 , 18 mod 71 >
# 19 mod 781 = < 8 mod 11 , 19 mod 71 >
# 20 mod 781 = < 9 mod 11 , 20 mod 71 >
# 21 mod 781 = < 10 mod 11 , 21 mod 71 >
# 22 mod 781 = < 0 mod 11 , 22 mod 71 >   a zero tells us it's NOT relatively prime
# 23 mod 781 = < 1 mod 11 , 23 mod 71 >
# 24 mod 781 = < 2 mod 11 , 24 mod 71 >
# 25 mod 781 = < 3 mod 11 , 25 mod 71 >
# 26 mod 781 = < 4 mod 11 , 26 mod 71 >
# 27 mod 781 = < 5 mod 11 , 27 mod 71 >
# 28 mod 781 = < 6 mod 11 , 28 mod 71 >
# 29 mod 781 = < 7 mod 11 , 29 mod 71 >
# 30 mod 781 = < 8 mod 11 , 30 mod 71 >
# 31 mod 781 = < 9 mod 11 , 31 mod 71 >
# 32 mod 781 = < 10 mod 11 , 32 mod 71 >
# 33 mod 781 = < 0 mod 11 , 33 mod 71 >   a zero tells us it's NOT relatively prime
# 34 mod 781 = < 1 mod 11 , 34 mod 71 >
# 35 mod 781 = < 2 mod 11 , 35 mod 71 >
# 36 mod 781 = < 3 mod 11 , 36 mod 71 >
# 37 mod 781 = < 4 mod 11 , 37 mod 71 >
# 38 mod 781 = < 5 mod 11 , 38 mod 71 >
# 39 mod 781 = < 6 mod 11 , 39 mod 71 >
# 40 mod 781 = < 7 mod 11 , 40 mod 71 >
# 41 mod 781 = < 8 mod 11 , 41 mod 71 >
# 42 mod 781 = < 9 mod 11 , 42 mod 71 >
# 43 mod 781 = < 10 mod 11 , 43 mod 71 >
# 44 mod 781 = < 0 mod 11 , 44 mod 71 >   a zero tells us it's NOT relatively prime
# 45 mod 781 = < 1 mod 11 , 45 mod 71 >
# 46 mod 781 = < 2 mod 11 , 46 mod 71 >
# 47 mod 781 = < 3 mod 11 , 47 mod 71 >
# 48 mod 781 = < 4 mod 11 , 48 mod 71 >
# 49 mod 781 = < 5 mod 11 , 49 mod 71 >
# 50 mod 781 = < 6 mod 11 , 50 mod 71 >
# 51 mod 781 = < 7 mod 11 , 51 mod 71 >
# 52 mod 781 = < 8 mod 11 , 52 mod 71 >
# 53 mod 781 = < 9 mod 11 , 53 mod 71 >
# 54 mod 781 = < 10 mod 11 , 54 mod 71 >
# 55 mod 781 = < 0 mod 11 , 55 mod 71 >   a zero tells us it's NOT relatively prime
# 56 mod 781 = < 1 mod 11 , 56 mod 71 >
# 57 mod 781 = < 2 mod 11 , 57 mod 71 >
# 58 mod 781 = < 3 mod 11 , 58 mod 71 >
# 59 mod 781 = < 4 mod 11 , 59 mod 71 >
# 60 mod 781 = < 5 mod 11 , 60 mod 71 >
# 61 mod 781 = < 6 mod 11 , 61 mod 71 >
# 62 mod 781 = < 7 mod 11 , 62 mod 71 >
# 63 mod 781 = < 8 mod 11 , 63 mod 71 >
# 64 mod 781 = < 9 mod 11 , 64 mod 71 >
# 65 mod 781 = < 10 mod 11 , 65 mod 71 >
# 66 mod 781 = < 0 mod 11 , 66 mod 71 >   a zero tells us it's NOT relatively prime
# 67 mod 781 = < 1 mod 11 , 67 mod 71 >
# 68 mod 781 = < 2 mod 11 , 68 mod 71 >
# 69 mod 781 = < 3 mod 11 , 69 mod 71 >
# 70 mod 781 = < 4 mod 11 , 70 mod 71 >
# 71 mod 781 = < 5 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 72 mod 781 = < 6 mod 11 , 1 mod 71 >
# 73 mod 781 = < 7 mod 11 , 2 mod 71 >
# 74 mod 781 = < 8 mod 11 , 3 mod 71 >
# 75 mod 781 = < 9 mod 11 , 4 mod 71 >
# 76 mod 781 = < 10 mod 11 , 5 mod 71 >
# 77 mod 781 = < 0 mod 11 , 6 mod 71 >   a zero tells us it's NOT relatively prime
# 78 mod 781 = < 1 mod 11 , 7 mod 71 >
# 79 mod 781 = < 2 mod 11 , 8 mod 71 >
# 80 mod 781 = < 3 mod 11 , 9 mod 71 >
# 81 mod 781 = < 4 mod 11 , 10 mod 71 >
# 82 mod 781 = < 5 mod 11 , 11 mod 71 >
# 83 mod 781 = < 6 mod 11 , 12 mod 71 >
# 84 mod 781 = < 7 mod 11 , 13 mod 71 >
# 85 mod 781 = < 8 mod 11 , 14 mod 71 >
# 86 mod 781 = < 9 mod 11 , 15 mod 71 >
# 87 mod 781 = < 10 mod 11 , 16 mod 71 >
# 88 mod 781 = < 0 mod 11 , 17 mod 71 >   a zero tells us it's NOT relatively prime
# 89 mod 781 = < 1 mod 11 , 18 mod 71 >
# 90 mod 781 = < 2 mod 11 , 19 mod 71 >
# 91 mod 781 = < 3 mod 11 , 20 mod 71 >
# 92 mod 781 = < 4 mod 11 , 21 mod 71 >
# 93 mod 781 = < 5 mod 11 , 22 mod 71 >
# 94 mod 781 = < 6 mod 11 , 23 mod 71 >
# 95 mod 781 = < 7 mod 11 , 24 mod 71 >
# 96 mod 781 = < 8 mod 11 , 25 mod 71 >
# 97 mod 781 = < 9 mod 11 , 26 mod 71 >
# 98 mod 781 = < 10 mod 11 , 27 mod 71 >
# 99 mod 781 = < 0 mod 11 , 28 mod 71 >   a zero tells us it's NOT relatively prime
# 100 mod 781 = < 1 mod 11 , 29 mod 71 >
# 101 mod 781 = < 2 mod 11 , 30 mod 71 >
# 102 mod 781 = < 3 mod 11 , 31 mod 71 >
# 103 mod 781 = < 4 mod 11 , 32 mod 71 >
# 104 mod 781 = < 5 mod 11 , 33 mod 71 >
# 105 mod 781 = < 6 mod 11 , 34 mod 71 >
# 106 mod 781 = < 7 mod 11 , 35 mod 71 >
# 107 mod 781 = < 8 mod 11 , 36 mod 71 >
# 108 mod 781 = < 9 mod 11 , 37 mod 71 >
# 109 mod 781 = < 10 mod 11 , 38 mod 71 >
# 110 mod 781 = < 0 mod 11 , 39 mod 71 >   a zero tells us it's NOT relatively prime
# 111 mod 781 = < 1 mod 11 , 40 mod 71 >
# 112 mod 781 = < 2 mod 11 , 41 mod 71 >
# 113 mod 781 = < 3 mod 11 , 42 mod 71 >
# 114 mod 781 = < 4 mod 11 , 43 mod 71 >
# 115 mod 781 = < 5 mod 11 , 44 mod 71 >
# 116 mod 781 = < 6 mod 11 , 45 mod 71 >
# 117 mod 781 = < 7 mod 11 , 46 mod 71 >
# 118 mod 781 = < 8 mod 11 , 47 mod 71 >
# 119 mod 781 = < 9 mod 11 , 48 mod 71 >
# 120 mod 781 = < 10 mod 11 , 49 mod 71 >
# 121 mod 781 = < 0 mod 11 , 50 mod 71 >   a zero tells us it's NOT relatively prime
# 122 mod 781 = < 1 mod 11 , 51 mod 71 >
# 123 mod 781 = < 2 mod 11 , 52 mod 71 >
# 124 mod 781 = < 3 mod 11 , 53 mod 71 >
# 125 mod 781 = < 4 mod 11 , 54 mod 71 >
# 126 mod 781 = < 5 mod 11 , 55 mod 71 >
# 127 mod 781 = < 6 mod 11 , 56 mod 71 >
# 128 mod 781 = < 7 mod 11 , 57 mod 71 >
# 129 mod 781 = < 8 mod 11 , 58 mod 71 >
# 130 mod 781 = < 9 mod 11 , 59 mod 71 >
# 131 mod 781 = < 10 mod 11 , 60 mod 71 >
# 132 mod 781 = < 0 mod 11 , 61 mod 71 >   a zero tells us it's NOT relatively prime
# 133 mod 781 = < 1 mod 11 , 62 mod 71 >
# 134 mod 781 = < 2 mod 11 , 63 mod 71 >
# 135 mod 781 = < 3 mod 11 , 64 mod 71 >
# 136 mod 781 = < 4 mod 11 , 65 mod 71 >
# 137 mod 781 = < 5 mod 11 , 66 mod 71 >
# 138 mod 781 = < 6 mod 11 , 67 mod 71 >
# 139 mod 781 = < 7 mod 11 , 68 mod 71 >
# 140 mod 781 = < 8 mod 11 , 69 mod 71 >
# 141 mod 781 = < 9 mod 11 , 70 mod 71 >
# 142 mod 781 = < 10 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 143 mod 781 = < 0 mod 11 , 1 mod 71 >   a zero tells us it's NOT relatively prime
# 144 mod 781 = < 1 mod 11 , 2 mod 71 >
# 145 mod 781 = < 2 mod 11 , 3 mod 71 >
# 146 mod 781 = < 3 mod 11 , 4 mod 71 >
# 147 mod 781 = < 4 mod 11 , 5 mod 71 >
# 148 mod 781 = < 5 mod 11 , 6 mod 71 >
# 149 mod 781 = < 6 mod 11 , 7 mod 71 >
# 150 mod 781 = < 7 mod 11 , 8 mod 71 >
# 151 mod 781 = < 8 mod 11 , 9 mod 71 >
# 152 mod 781 = < 9 mod 11 , 10 mod 71 >
# 153 mod 781 = < 10 mod 11 , 11 mod 71 >
# 154 mod 781 = < 0 mod 11 , 12 mod 71 >   a zero tells us it's NOT relatively prime
# 155 mod 781 = < 1 mod 11 , 13 mod 71 >
# 156 mod 781 = < 2 mod 11 , 14 mod 71 >
# 157 mod 781 = < 3 mod 11 , 15 mod 71 >
# 158 mod 781 = < 4 mod 11 , 16 mod 71 >
# 159 mod 781 = < 5 mod 11 , 17 mod 71 >
# 160 mod 781 = < 6 mod 11 , 18 mod 71 >
# 161 mod 781 = < 7 mod 11 , 19 mod 71 >
# 162 mod 781 = < 8 mod 11 , 20 mod 71 >
# 163 mod 781 = < 9 mod 11 , 21 mod 71 >
# 164 mod 781 = < 10 mod 11 , 22 mod 71 >
# 165 mod 781 = < 0 mod 11 , 23 mod 71 >   a zero tells us it's NOT relatively prime
# 166 mod 781 = < 1 mod 11 , 24 mod 71 >
# 167 mod 781 = < 2 mod 11 , 25 mod 71 >
# 168 mod 781 = < 3 mod 11 , 26 mod 71 >
# 169 mod 781 = < 4 mod 11 , 27 mod 71 >
# 170 mod 781 = < 5 mod 11 , 28 mod 71 >
# 171 mod 781 = < 6 mod 11 , 29 mod 71 >
# 172 mod 781 = < 7 mod 11 , 30 mod 71 >
# 173 mod 781 = < 8 mod 11 , 31 mod 71 >
# 174 mod 781 = < 9 mod 11 , 32 mod 71 >
# 175 mod 781 = < 10 mod 11 , 33 mod 71 >
# 176 mod 781 = < 0 mod 11 , 34 mod 71 >   a zero tells us it's NOT relatively prime
# 177 mod 781 = < 1 mod 11 , 35 mod 71 >
# 178 mod 781 = < 2 mod 11 , 36 mod 71 >
# 179 mod 781 = < 3 mod 11 , 37 mod 71 >
# 180 mod 781 = < 4 mod 11 , 38 mod 71 >
# 181 mod 781 = < 5 mod 11 , 39 mod 71 >
# 182 mod 781 = < 6 mod 11 , 40 mod 71 >
# 183 mod 781 = < 7 mod 11 , 41 mod 71 >
# 184 mod 781 = < 8 mod 11 , 42 mod 71 >
# 185 mod 781 = < 9 mod 11 , 43 mod 71 >
# 186 mod 781 = < 10 mod 11 , 44 mod 71 >
# 187 mod 781 = < 0 mod 11 , 45 mod 71 >   a zero tells us it's NOT relatively prime
# 188 mod 781 = < 1 mod 11 , 46 mod 71 >
# 189 mod 781 = < 2 mod 11 , 47 mod 71 >
# 190 mod 781 = < 3 mod 11 , 48 mod 71 >
# 191 mod 781 = < 4 mod 11 , 49 mod 71 >
# 192 mod 781 = < 5 mod 11 , 50 mod 71 >
# 193 mod 781 = < 6 mod 11 , 51 mod 71 >
# 194 mod 781 = < 7 mod 11 , 52 mod 71 >
# 195 mod 781 = < 8 mod 11 , 53 mod 71 >
# 196 mod 781 = < 9 mod 11 , 54 mod 71 >
# 197 mod 781 = < 10 mod 11 , 55 mod 71 >
# 198 mod 781 = < 0 mod 11 , 56 mod 71 >   a zero tells us it's NOT relatively prime
# 199 mod 781 = < 1 mod 11 , 57 mod 71 >
# 200 mod 781 = < 2 mod 11 , 58 mod 71 >
# 201 mod 781 = < 3 mod 11 , 59 mod 71 >
# 202 mod 781 = < 4 mod 11 , 60 mod 71 >
# 203 mod 781 = < 5 mod 11 , 61 mod 71 >
# 204 mod 781 = < 6 mod 11 , 62 mod 71 >
# 205 mod 781 = < 7 mod 11 , 63 mod 71 >
# 206 mod 781 = < 8 mod 11 , 64 mod 71 >
# 207 mod 781 = < 9 mod 11 , 65 mod 71 >
# 208 mod 781 = < 10 mod 11 , 66 mod 71 >
# 209 mod 781 = < 0 mod 11 , 67 mod 71 >   a zero tells us it's NOT relatively prime
# 210 mod 781 = < 1 mod 11 , 68 mod 71 >
# 211 mod 781 = < 2 mod 11 , 69 mod 71 >
# 212 mod 781 = < 3 mod 11 , 70 mod 71 >
# 213 mod 781 = < 4 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 214 mod 781 = < 5 mod 11 , 1 mod 71 >
# 215 mod 781 = < 6 mod 11 , 2 mod 71 >
# 216 mod 781 = < 7 mod 11 , 3 mod 71 >
# 217 mod 781 = < 8 mod 11 , 4 mod 71 >
# 218 mod 781 = < 9 mod 11 , 5 mod 71 >
# 219 mod 781 = < 10 mod 11 , 6 mod 71 >
# 220 mod 781 = < 0 mod 11 , 7 mod 71 >   a zero tells us it's NOT relatively prime
# 221 mod 781 = < 1 mod 11 , 8 mod 71 >
# 222 mod 781 = < 2 mod 11 , 9 mod 71 >
# 223 mod 781 = < 3 mod 11 , 10 mod 71 >
# 224 mod 781 = < 4 mod 11 , 11 mod 71 >
# 225 mod 781 = < 5 mod 11 , 12 mod 71 >
# 226 mod 781 = < 6 mod 11 , 13 mod 71 >
# 227 mod 781 = < 7 mod 11 , 14 mod 71 >
# 228 mod 781 = < 8 mod 11 , 15 mod 71 >
# 229 mod 781 = < 9 mod 11 , 16 mod 71 >
# 230 mod 781 = < 10 mod 11 , 17 mod 71 >
# 231 mod 781 = < 0 mod 11 , 18 mod 71 >   a zero tells us it's NOT relatively prime
# 232 mod 781 = < 1 mod 11 , 19 mod 71 >
# 233 mod 781 = < 2 mod 11 , 20 mod 71 >
# 234 mod 781 = < 3 mod 11 , 21 mod 71 >
# 235 mod 781 = < 4 mod 11 , 22 mod 71 >
# 236 mod 781 = < 5 mod 11 , 23 mod 71 >
# 237 mod 781 = < 6 mod 11 , 24 mod 71 >
# 238 mod 781 = < 7 mod 11 , 25 mod 71 >
# 239 mod 781 = < 8 mod 11 , 26 mod 71 >
# 240 mod 781 = < 9 mod 11 , 27 mod 71 >
# 241 mod 781 = < 10 mod 11 , 28 mod 71 >
# 242 mod 781 = < 0 mod 11 , 29 mod 71 >   a zero tells us it's NOT relatively prime
# 243 mod 781 = < 1 mod 11 , 30 mod 71 >
# 244 mod 781 = < 2 mod 11 , 31 mod 71 >
# 245 mod 781 = < 3 mod 11 , 32 mod 71 >
# 246 mod 781 = < 4 mod 11 , 33 mod 71 >
# 247 mod 781 = < 5 mod 11 , 34 mod 71 >
# 248 mod 781 = < 6 mod 11 , 35 mod 71 >
# 249 mod 781 = < 7 mod 11 , 36 mod 71 >
# 250 mod 781 = < 8 mod 11 , 37 mod 71 >
# 251 mod 781 = < 9 mod 11 , 38 mod 71 >
# 252 mod 781 = < 10 mod 11 , 39 mod 71 >
# 253 mod 781 = < 0 mod 11 , 40 mod 71 >   a zero tells us it's NOT relatively prime
# 254 mod 781 = < 1 mod 11 , 41 mod 71 >
# 255 mod 781 = < 2 mod 11 , 42 mod 71 >
# 256 mod 781 = < 3 mod 11 , 43 mod 71 >
# 257 mod 781 = < 4 mod 11 , 44 mod 71 >
# 258 mod 781 = < 5 mod 11 , 45 mod 71 >
# 259 mod 781 = < 6 mod 11 , 46 mod 71 >
# 260 mod 781 = < 7 mod 11 , 47 mod 71 >
# 261 mod 781 = < 8 mod 11 , 48 mod 71 >
# 262 mod 781 = < 9 mod 11 , 49 mod 71 >
# 263 mod 781 = < 10 mod 11 , 50 mod 71 >
# 264 mod 781 = < 0 mod 11 , 51 mod 71 >   a zero tells us it's NOT relatively prime
# 265 mod 781 = < 1 mod 11 , 52 mod 71 >
# 266 mod 781 = < 2 mod 11 , 53 mod 71 >
# 267 mod 781 = < 3 mod 11 , 54 mod 71 >
# 268 mod 781 = < 4 mod 11 , 55 mod 71 >
# 269 mod 781 = < 5 mod 11 , 56 mod 71 >
# 270 mod 781 = < 6 mod 11 , 57 mod 71 >
# 271 mod 781 = < 7 mod 11 , 58 mod 71 >
# 272 mod 781 = < 8 mod 11 , 59 mod 71 >
# 273 mod 781 = < 9 mod 11 , 60 mod 71 >
# 274 mod 781 = < 10 mod 11 , 61 mod 71 >
# 275 mod 781 = < 0 mod 11 , 62 mod 71 >   a zero tells us it's NOT relatively prime
# 276 mod 781 = < 1 mod 11 , 63 mod 71 >
# 277 mod 781 = < 2 mod 11 , 64 mod 71 >
# 278 mod 781 = < 3 mod 11 , 65 mod 71 >
# 279 mod 781 = < 4 mod 11 , 66 mod 71 >
# 280 mod 781 = < 5 mod 11 , 67 mod 71 >
# 281 mod 781 = < 6 mod 11 , 68 mod 71 >
# 282 mod 781 = < 7 mod 11 , 69 mod 71 >
# 283 mod 781 = < 8 mod 11 , 70 mod 71 >
# 284 mod 781 = < 9 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 285 mod 781 = < 10 mod 11 , 1 mod 71 >
# 286 mod 781 = < 0 mod 11 , 2 mod 71 >   a zero tells us it's NOT relatively prime
# 287 mod 781 = < 1 mod 11 , 3 mod 71 >
# 288 mod 781 = < 2 mod 11 , 4 mod 71 >
# 289 mod 781 = < 3 mod 11 , 5 mod 71 >
# 290 mod 781 = < 4 mod 11 , 6 mod 71 >
# 291 mod 781 = < 5 mod 11 , 7 mod 71 >
# 292 mod 781 = < 6 mod 11 , 8 mod 71 >
# 293 mod 781 = < 7 mod 11 , 9 mod 71 >
# 294 mod 781 = < 8 mod 11 , 10 mod 71 >
# 295 mod 781 = < 9 mod 11 , 11 mod 71 >
# 296 mod 781 = < 10 mod 11 , 12 mod 71 >
# 297 mod 781 = < 0 mod 11 , 13 mod 71 >   a zero tells us it's NOT relatively prime
# 298 mod 781 = < 1 mod 11 , 14 mod 71 >
# 299 mod 781 = < 2 mod 11 , 15 mod 71 >
# 300 mod 781 = < 3 mod 11 , 16 mod 71 >
# 301 mod 781 = < 4 mod 11 , 17 mod 71 >
# 302 mod 781 = < 5 mod 11 , 18 mod 71 >
# 303 mod 781 = < 6 mod 11 , 19 mod 71 >
# 304 mod 781 = < 7 mod 11 , 20 mod 71 >
# 305 mod 781 = < 8 mod 11 , 21 mod 71 >
# 306 mod 781 = < 9 mod 11 , 22 mod 71 >
# 307 mod 781 = < 10 mod 11 , 23 mod 71 >
# 308 mod 781 = < 0 mod 11 , 24 mod 71 >   a zero tells us it's NOT relatively prime
# 309 mod 781 = < 1 mod 11 , 25 mod 71 >
# 310 mod 781 = < 2 mod 11 , 26 mod 71 >
# 311 mod 781 = < 3 mod 11 , 27 mod 71 >
# 312 mod 781 = < 4 mod 11 , 28 mod 71 >
# 313 mod 781 = < 5 mod 11 , 29 mod 71 >
# 314 mod 781 = < 6 mod 11 , 30 mod 71 >
# 315 mod 781 = < 7 mod 11 , 31 mod 71 >
# 316 mod 781 = < 8 mod 11 , 32 mod 71 >
# 317 mod 781 = < 9 mod 11 , 33 mod 71 >
# 318 mod 781 = < 10 mod 11 , 34 mod 71 >
# 319 mod 781 = < 0 mod 11 , 35 mod 71 >   a zero tells us it's NOT relatively prime
# 320 mod 781 = < 1 mod 11 , 36 mod 71 >
# 321 mod 781 = < 2 mod 11 , 37 mod 71 >
# 322 mod 781 = < 3 mod 11 , 38 mod 71 >
# 323 mod 781 = < 4 mod 11 , 39 mod 71 >
# 324 mod 781 = < 5 mod 11 , 40 mod 71 >
# 325 mod 781 = < 6 mod 11 , 41 mod 71 >
# 326 mod 781 = < 7 mod 11 , 42 mod 71 >
# 327 mod 781 = < 8 mod 11 , 43 mod 71 >
# 328 mod 781 = < 9 mod 11 , 44 mod 71 >
# 329 mod 781 = < 10 mod 11 , 45 mod 71 >
# 330 mod 781 = < 0 mod 11 , 46 mod 71 >   a zero tells us it's NOT relatively prime
# 331 mod 781 = < 1 mod 11 , 47 mod 71 >
# 332 mod 781 = < 2 mod 11 , 48 mod 71 >
# 333 mod 781 = < 3 mod 11 , 49 mod 71 >
# 334 mod 781 = < 4 mod 11 , 50 mod 71 >
# 335 mod 781 = < 5 mod 11 , 51 mod 71 >
# 336 mod 781 = < 6 mod 11 , 52 mod 71 >
# 337 mod 781 = < 7 mod 11 , 53 mod 71 >
# 338 mod 781 = < 8 mod 11 , 54 mod 71 >
# 339 mod 781 = < 9 mod 11 , 55 mod 71 >
# 340 mod 781 = < 10 mod 11 , 56 mod 71 >
# 341 mod 781 = < 0 mod 11 , 57 mod 71 >   a zero tells us it's NOT relatively prime
# 342 mod 781 = < 1 mod 11 , 58 mod 71 >
# 343 mod 781 = < 2 mod 11 , 59 mod 71 >
# 344 mod 781 = < 3 mod 11 , 60 mod 71 >
# 345 mod 781 = < 4 mod 11 , 61 mod 71 >
# 346 mod 781 = < 5 mod 11 , 62 mod 71 >
# 347 mod 781 = < 6 mod 11 , 63 mod 71 >
# 348 mod 781 = < 7 mod 11 , 64 mod 71 >
# 349 mod 781 = < 8 mod 11 , 65 mod 71 >
# 350 mod 781 = < 9 mod 11 , 66 mod 71 >
# 351 mod 781 = < 10 mod 11 , 67 mod 71 >
# 352 mod 781 = < 0 mod 11 , 68 mod 71 >   a zero tells us it's NOT relatively prime
# 353 mod 781 = < 1 mod 11 , 69 mod 71 >
# 354 mod 781 = < 2 mod 11 , 70 mod 71 >
# 355 mod 781 = < 3 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 356 mod 781 = < 4 mod 11 , 1 mod 71 >
# 357 mod 781 = < 5 mod 11 , 2 mod 71 >
# 358 mod 781 = < 6 mod 11 , 3 mod 71 >
# 359 mod 781 = < 7 mod 11 , 4 mod 71 >
# 360 mod 781 = < 8 mod 11 , 5 mod 71 >
# 361 mod 781 = < 9 mod 11 , 6 mod 71 >
# 362 mod 781 = < 10 mod 11 , 7 mod 71 >
# 363 mod 781 = < 0 mod 11 , 8 mod 71 >   a zero tells us it's NOT relatively prime
# 364 mod 781 = < 1 mod 11 , 9 mod 71 >
# 365 mod 781 = < 2 mod 11 , 10 mod 71 >
# 366 mod 781 = < 3 mod 11 , 11 mod 71 >
# 367 mod 781 = < 4 mod 11 , 12 mod 71 >
# 368 mod 781 = < 5 mod 11 , 13 mod 71 >
# 369 mod 781 = < 6 mod 11 , 14 mod 71 >
# 370 mod 781 = < 7 mod 11 , 15 mod 71 >
# 371 mod 781 = < 8 mod 11 , 16 mod 71 >
# 372 mod 781 = < 9 mod 11 , 17 mod 71 >
# 373 mod 781 = < 10 mod 11 , 18 mod 71 >
# 374 mod 781 = < 0 mod 11 , 19 mod 71 >   a zero tells us it's NOT relatively prime
# 375 mod 781 = < 1 mod 11 , 20 mod 71 >
# 376 mod 781 = < 2 mod 11 , 21 mod 71 >
# 377 mod 781 = < 3 mod 11 , 22 mod 71 >
# 378 mod 781 = < 4 mod 11 , 23 mod 71 >
# 379 mod 781 = < 5 mod 11 , 24 mod 71 >
# 380 mod 781 = < 6 mod 11 , 25 mod 71 >
# 381 mod 781 = < 7 mod 11 , 26 mod 71 >
# 382 mod 781 = < 8 mod 11 , 27 mod 71 >
# 383 mod 781 = < 9 mod 11 , 28 mod 71 >
# 384 mod 781 = < 10 mod 11 , 29 mod 71 >
# 385 mod 781 = < 0 mod 11 , 30 mod 71 >   a zero tells us it's NOT relatively prime
# 386 mod 781 = < 1 mod 11 , 31 mod 71 >
# 387 mod 781 = < 2 mod 11 , 32 mod 71 >
# 388 mod 781 = < 3 mod 11 , 33 mod 71 >
# 389 mod 781 = < 4 mod 11 , 34 mod 71 >
# 390 mod 781 = < 5 mod 11 , 35 mod 71 >
# 391 mod 781 = < 6 mod 11 , 36 mod 71 >
# 392 mod 781 = < 7 mod 11 , 37 mod 71 >
# 393 mod 781 = < 8 mod 11 , 38 mod 71 >
# 394 mod 781 = < 9 mod 11 , 39 mod 71 >
# 395 mod 781 = < 10 mod 11 , 40 mod 71 >
# 396 mod 781 = < 0 mod 11 , 41 mod 71 >   a zero tells us it's NOT relatively prime
# 397 mod 781 = < 1 mod 11 , 42 mod 71 >
# 398 mod 781 = < 2 mod 11 , 43 mod 71 >
# 399 mod 781 = < 3 mod 11 , 44 mod 71 >
# 400 mod 781 = < 4 mod 11 , 45 mod 71 >
# 401 mod 781 = < 5 mod 11 , 46 mod 71 >
# 402 mod 781 = < 6 mod 11 , 47 mod 71 >
# 403 mod 781 = < 7 mod 11 , 48 mod 71 >
# 404 mod 781 = < 8 mod 11 , 49 mod 71 >
# 405 mod 781 = < 9 mod 11 , 50 mod 71 >
# 406 mod 781 = < 10 mod 11 , 51 mod 71 >
# 407 mod 781 = < 0 mod 11 , 52 mod 71 >   a zero tells us it's NOT relatively prime
# 408 mod 781 = < 1 mod 11 , 53 mod 71 >
# 409 mod 781 = < 2 mod 11 , 54 mod 71 >
# 410 mod 781 = < 3 mod 11 , 55 mod 71 >
# 411 mod 781 = < 4 mod 11 , 56 mod 71 >
# 412 mod 781 = < 5 mod 11 , 57 mod 71 >
# 413 mod 781 = < 6 mod 11 , 58 mod 71 >
# 414 mod 781 = < 7 mod 11 , 59 mod 71 >
# 415 mod 781 = < 8 mod 11 , 60 mod 71 >
# 416 mod 781 = < 9 mod 11 , 61 mod 71 >
# 417 mod 781 = < 10 mod 11 , 62 mod 71 >
# 418 mod 781 = < 0 mod 11 , 63 mod 71 >   a zero tells us it's NOT relatively prime
# 419 mod 781 = < 1 mod 11 , 64 mod 71 >
# 420 mod 781 = < 2 mod 11 , 65 mod 71 >
# 421 mod 781 = < 3 mod 11 , 66 mod 71 >
# 422 mod 781 = < 4 mod 11 , 67 mod 71 >
# 423 mod 781 = < 5 mod 11 , 68 mod 71 >
# 424 mod 781 = < 6 mod 11 , 69 mod 71 >
# 425 mod 781 = < 7 mod 11 , 70 mod 71 >
# 426 mod 781 = < 8 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 427 mod 781 = < 9 mod 11 , 1 mod 71 >
# 428 mod 781 = < 10 mod 11 , 2 mod 71 >
# 429 mod 781 = < 0 mod 11 , 3 mod 71 >   a zero tells us it's NOT relatively prime
# 430 mod 781 = < 1 mod 11 , 4 mod 71 >
# 431 mod 781 = < 2 mod 11 , 5 mod 71 >
# 432 mod 781 = < 3 mod 11 , 6 mod 71 >
# 433 mod 781 = < 4 mod 11 , 7 mod 71 >
# 434 mod 781 = < 5 mod 11 , 8 mod 71 >
# 435 mod 781 = < 6 mod 11 , 9 mod 71 >
# 436 mod 781 = < 7 mod 11 , 10 mod 71 >
# 437 mod 781 = < 8 mod 11 , 11 mod 71 >
# 438 mod 781 = < 9 mod 11 , 12 mod 71 >
# 439 mod 781 = < 10 mod 11 , 13 mod 71 >
# 440 mod 781 = < 0 mod 11 , 14 mod 71 >   a zero tells us it's NOT relatively prime
# 441 mod 781 = < 1 mod 11 , 15 mod 71 >
# 442 mod 781 = < 2 mod 11 , 16 mod 71 >
# 443 mod 781 = < 3 mod 11 , 17 mod 71 >
# 444 mod 781 = < 4 mod 11 , 18 mod 71 >
# 445 mod 781 = < 5 mod 11 , 19 mod 71 >
# 446 mod 781 = < 6 mod 11 , 20 mod 71 >
# 447 mod 781 = < 7 mod 11 , 21 mod 71 >
# 448 mod 781 = < 8 mod 11 , 22 mod 71 >
# 449 mod 781 = < 9 mod 11 , 23 mod 71 >
# 450 mod 781 = < 10 mod 11 , 24 mod 71 >
# 451 mod 781 = < 0 mod 11 , 25 mod 71 >   a zero tells us it's NOT relatively prime
# 452 mod 781 = < 1 mod 11 , 26 mod 71 >
# 453 mod 781 = < 2 mod 11 , 27 mod 71 >
# 454 mod 781 = < 3 mod 11 , 28 mod 71 >
# 455 mod 781 = < 4 mod 11 , 29 mod 71 >
# 456 mod 781 = < 5 mod 11 , 30 mod 71 >
# 457 mod 781 = < 6 mod 11 , 31 mod 71 >
# 458 mod 781 = < 7 mod 11 , 32 mod 71 >
# 459 mod 781 = < 8 mod 11 , 33 mod 71 >
# 460 mod 781 = < 9 mod 11 , 34 mod 71 >
# 461 mod 781 = < 10 mod 11 , 35 mod 71 >
# 462 mod 781 = < 0 mod 11 , 36 mod 71 >   a zero tells us it's NOT relatively prime
# 463 mod 781 = < 1 mod 11 , 37 mod 71 >
# 464 mod 781 = < 2 mod 11 , 38 mod 71 >
# 465 mod 781 = < 3 mod 11 , 39 mod 71 >
# 466 mod 781 = < 4 mod 11 , 40 mod 71 >
# 467 mod 781 = < 5 mod 11 , 41 mod 71 >
# 468 mod 781 = < 6 mod 11 , 42 mod 71 >
# 469 mod 781 = < 7 mod 11 , 43 mod 71 >
# 470 mod 781 = < 8 mod 11 , 44 mod 71 >
# 471 mod 781 = < 9 mod 11 , 45 mod 71 >
# 472 mod 781 = < 10 mod 11 , 46 mod 71 >
# 473 mod 781 = < 0 mod 11 , 47 mod 71 >   a zero tells us it's NOT relatively prime
# 474 mod 781 = < 1 mod 11 , 48 mod 71 >
# 475 mod 781 = < 2 mod 11 , 49 mod 71 >
# 476 mod 781 = < 3 mod 11 , 50 mod 71 >
# 477 mod 781 = < 4 mod 11 , 51 mod 71 >
# 478 mod 781 = < 5 mod 11 , 52 mod 71 >
# 479 mod 781 = < 6 mod 11 , 53 mod 71 >
# 480 mod 781 = < 7 mod 11 , 54 mod 71 >
# 481 mod 781 = < 8 mod 11 , 55 mod 71 >
# 482 mod 781 = < 9 mod 11 , 56 mod 71 >
# 483 mod 781 = < 10 mod 11 , 57 mod 71 >
# 484 mod 781 = < 0 mod 11 , 58 mod 71 >   a zero tells us it's NOT relatively prime
# 485 mod 781 = < 1 mod 11 , 59 mod 71 >
# 486 mod 781 = < 2 mod 11 , 60 mod 71 >
# 487 mod 781 = < 3 mod 11 , 61 mod 71 >
# 488 mod 781 = < 4 mod 11 , 62 mod 71 >
# 489 mod 781 = < 5 mod 11 , 63 mod 71 >
# 490 mod 781 = < 6 mod 11 , 64 mod 71 >
# 491 mod 781 = < 7 mod 11 , 65 mod 71 >
# 492 mod 781 = < 8 mod 11 , 66 mod 71 >
# 493 mod 781 = < 9 mod 11 , 67 mod 71 >
# 494 mod 781 = < 10 mod 11 , 68 mod 71 >
# 495 mod 781 = < 0 mod 11 , 69 mod 71 >   a zero tells us it's NOT relatively prime
# 496 mod 781 = < 1 mod 11 , 70 mod 71 >
# 497 mod 781 = < 2 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 498 mod 781 = < 3 mod 11 , 1 mod 71 >
# 499 mod 781 = < 4 mod 11 , 2 mod 71 >
# 500 mod 781 = < 5 mod 11 , 3 mod 71 >
# 501 mod 781 = < 6 mod 11 , 4 mod 71 >
# 502 mod 781 = < 7 mod 11 , 5 mod 71 >
# 503 mod 781 = < 8 mod 11 , 6 mod 71 >
# 504 mod 781 = < 9 mod 11 , 7 mod 71 >
# 505 mod 781 = < 10 mod 11 , 8 mod 71 >
# 506 mod 781 = < 0 mod 11 , 9 mod 71 >   a zero tells us it's NOT relatively prime
# 507 mod 781 = < 1 mod 11 , 10 mod 71 >
# 508 mod 781 = < 2 mod 11 , 11 mod 71 >
# 509 mod 781 = < 3 mod 11 , 12 mod 71 >
# 510 mod 781 = < 4 mod 11 , 13 mod 71 >
# 511 mod 781 = < 5 mod 11 , 14 mod 71 >
# 512 mod 781 = < 6 mod 11 , 15 mod 71 >
# 513 mod 781 = < 7 mod 11 , 16 mod 71 >
# 514 mod 781 = < 8 mod 11 , 17 mod 71 >
# 515 mod 781 = < 9 mod 11 , 18 mod 71 >
# 516 mod 781 = < 10 mod 11 , 19 mod 71 >
# 517 mod 781 = < 0 mod 11 , 20 mod 71 >   a zero tells us it's NOT relatively prime
# 518 mod 781 = < 1 mod 11 , 21 mod 71 >
# 519 mod 781 = < 2 mod 11 , 22 mod 71 >
# 520 mod 781 = < 3 mod 11 , 23 mod 71 >
# 521 mod 781 = < 4 mod 11 , 24 mod 71 >
# 522 mod 781 = < 5 mod 11 , 25 mod 71 >
# 523 mod 781 = < 6 mod 11 , 26 mod 71 >
# 524 mod 781 = < 7 mod 11 , 27 mod 71 >
# 525 mod 781 = < 8 mod 11 , 28 mod 71 >
# 526 mod 781 = < 9 mod 11 , 29 mod 71 >
# 527 mod 781 = < 10 mod 11 , 30 mod 71 >
# 528 mod 781 = < 0 mod 11 , 31 mod 71 >   a zero tells us it's NOT relatively prime
# 529 mod 781 = < 1 mod 11 , 32 mod 71 >
# 530 mod 781 = < 2 mod 11 , 33 mod 71 >
# 531 mod 781 = < 3 mod 11 , 34 mod 71 >
# 532 mod 781 = < 4 mod 11 , 35 mod 71 >
# 533 mod 781 = < 5 mod 11 , 36 mod 71 >
# 534 mod 781 = < 6 mod 11 , 37 mod 71 >
# 535 mod 781 = < 7 mod 11 , 38 mod 71 >
# 536 mod 781 = < 8 mod 11 , 39 mod 71 >
# 537 mod 781 = < 9 mod 11 , 40 mod 71 >
# 538 mod 781 = < 10 mod 11 , 41 mod 71 >
# 539 mod 781 = < 0 mod 11 , 42 mod 71 >   a zero tells us it's NOT relatively prime
# 540 mod 781 = < 1 mod 11 , 43 mod 71 >
# 541 mod 781 = < 2 mod 11 , 44 mod 71 >
# 542 mod 781 = < 3 mod 11 , 45 mod 71 >
# 543 mod 781 = < 4 mod 11 , 46 mod 71 >
# 544 mod 781 = < 5 mod 11 , 47 mod 71 >
# 545 mod 781 = < 6 mod 11 , 48 mod 71 >
# 546 mod 781 = < 7 mod 11 , 49 mod 71 >
# 547 mod 781 = < 8 mod 11 , 50 mod 71 >
# 548 mod 781 = < 9 mod 11 , 51 mod 71 >
# 549 mod 781 = < 10 mod 11 , 52 mod 71 >
# 550 mod 781 = < 0 mod 11 , 53 mod 71 >   a zero tells us it's NOT relatively prime
# 551 mod 781 = < 1 mod 11 , 54 mod 71 >
# 552 mod 781 = < 2 mod 11 , 55 mod 71 >
# 553 mod 781 = < 3 mod 11 , 56 mod 71 >
# 554 mod 781 = < 4 mod 11 , 57 mod 71 >
# 555 mod 781 = < 5 mod 11 , 58 mod 71 >
# 556 mod 781 = < 6 mod 11 , 59 mod 71 >
# 557 mod 781 = < 7 mod 11 , 60 mod 71 >
# 558 mod 781 = < 8 mod 11 , 61 mod 71 >
# 559 mod 781 = < 9 mod 11 , 62 mod 71 >
# 560 mod 781 = < 10 mod 11 , 63 mod 71 >
# 561 mod 781 = < 0 mod 11 , 64 mod 71 >   a zero tells us it's NOT relatively prime
# 562 mod 781 = < 1 mod 11 , 65 mod 71 >
# 563 mod 781 = < 2 mod 11 , 66 mod 71 >
# 564 mod 781 = < 3 mod 11 , 67 mod 71 >
# 565 mod 781 = < 4 mod 11 , 68 mod 71 >
# 566 mod 781 = < 5 mod 11 , 69 mod 71 >
# 567 mod 781 = < 6 mod 11 , 70 mod 71 >
# 568 mod 781 = < 7 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 569 mod 781 = < 8 mod 11 , 1 mod 71 >
# 570 mod 781 = < 9 mod 11 , 2 mod 71 >
# 571 mod 781 = < 10 mod 11 , 3 mod 71 >
# 572 mod 781 = < 0 mod 11 , 4 mod 71 >   a zero tells us it's NOT relatively prime
# 573 mod 781 = < 1 mod 11 , 5 mod 71 >
# 574 mod 781 = < 2 mod 11 , 6 mod 71 >
# 575 mod 781 = < 3 mod 11 , 7 mod 71 >
# 576 mod 781 = < 4 mod 11 , 8 mod 71 >
# 577 mod 781 = < 5 mod 11 , 9 mod 71 >
# 578 mod 781 = < 6 mod 11 , 10 mod 71 >
# 579 mod 781 = < 7 mod 11 , 11 mod 71 >
# 580 mod 781 = < 8 mod 11 , 12 mod 71 >
# 581 mod 781 = < 9 mod 11 , 13 mod 71 >
# 582 mod 781 = < 10 mod 11 , 14 mod 71 >
# 583 mod 781 = < 0 mod 11 , 15 mod 71 >   a zero tells us it's NOT relatively prime
# 584 mod 781 = < 1 mod 11 , 16 mod 71 >
# 585 mod 781 = < 2 mod 11 , 17 mod 71 >
# 586 mod 781 = < 3 mod 11 , 18 mod 71 >
# 587 mod 781 = < 4 mod 11 , 19 mod 71 >
# 588 mod 781 = < 5 mod 11 , 20 mod 71 >
# 589 mod 781 = < 6 mod 11 , 21 mod 71 >
# 590 mod 781 = < 7 mod 11 , 22 mod 71 >
# 591 mod 781 = < 8 mod 11 , 23 mod 71 >
# 592 mod 781 = < 9 mod 11 , 24 mod 71 >
# 593 mod 781 = < 10 mod 11 , 25 mod 71 >
# 594 mod 781 = < 0 mod 11 , 26 mod 71 >   a zero tells us it's NOT relatively prime
# 595 mod 781 = < 1 mod 11 , 27 mod 71 >
# 596 mod 781 = < 2 mod 11 , 28 mod 71 >
# 597 mod 781 = < 3 mod 11 , 29 mod 71 >
# 598 mod 781 = < 4 mod 11 , 30 mod 71 >
# 599 mod 781 = < 5 mod 11 , 31 mod 71 >
# 600 mod 781 = < 6 mod 11 , 32 mod 71 >
# 601 mod 781 = < 7 mod 11 , 33 mod 71 >
# 602 mod 781 = < 8 mod 11 , 34 mod 71 >
# 603 mod 781 = < 9 mod 11 , 35 mod 71 >
# 604 mod 781 = < 10 mod 11 , 36 mod 71 >
# 605 mod 781 = < 0 mod 11 , 37 mod 71 >   a zero tells us it's NOT relatively prime
# 606 mod 781 = < 1 mod 11 , 38 mod 71 >
# 607 mod 781 = < 2 mod 11 , 39 mod 71 >
# 608 mod 781 = < 3 mod 11 , 40 mod 71 >
# 609 mod 781 = < 4 mod 11 , 41 mod 71 >
# 610 mod 781 = < 5 mod 11 , 42 mod 71 >
# 611 mod 781 = < 6 mod 11 , 43 mod 71 >
# 612 mod 781 = < 7 mod 11 , 44 mod 71 >
# 613 mod 781 = < 8 mod 11 , 45 mod 71 >
# 614 mod 781 = < 9 mod 11 , 46 mod 71 >
# 615 mod 781 = < 10 mod 11 , 47 mod 71 >
# 616 mod 781 = < 0 mod 11 , 48 mod 71 >   a zero tells us it's NOT relatively prime
# 617 mod 781 = < 1 mod 11 , 49 mod 71 >
# 618 mod 781 = < 2 mod 11 , 50 mod 71 >
# 619 mod 781 = < 3 mod 11 , 51 mod 71 >
# 620 mod 781 = < 4 mod 11 , 52 mod 71 >
# 621 mod 781 = < 5 mod 11 , 53 mod 71 >
# 622 mod 781 = < 6 mod 11 , 54 mod 71 >
# 623 mod 781 = < 7 mod 11 , 55 mod 71 >
# 624 mod 781 = < 8 mod 11 , 56 mod 71 >
# 625 mod 781 = < 9 mod 11 , 57 mod 71 >
# 626 mod 781 = < 10 mod 11 , 58 mod 71 >
# 627 mod 781 = < 0 mod 11 , 59 mod 71 >   a zero tells us it's NOT relatively prime
# 628 mod 781 = < 1 mod 11 , 60 mod 71 >
# 629 mod 781 = < 2 mod 11 , 61 mod 71 >
# 630 mod 781 = < 3 mod 11 , 62 mod 71 >
# 631 mod 781 = < 4 mod 11 , 63 mod 71 >
# 632 mod 781 = < 5 mod 11 , 64 mod 71 >
# 633 mod 781 = < 6 mod 11 , 65 mod 71 >
# 634 mod 781 = < 7 mod 11 , 66 mod 71 >
# 635 mod 781 = < 8 mod 11 , 67 mod 71 >
# 636 mod 781 = < 9 mod 11 , 68 mod 71 >
# 637 mod 781 = < 10 mod 11 , 69 mod 71 >
# 638 mod 781 = < 0 mod 11 , 70 mod 71 >   a zero tells us it's NOT relatively prime
# 639 mod 781 = < 1 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 640 mod 781 = < 2 mod 11 , 1 mod 71 >
# 641 mod 781 = < 3 mod 11 , 2 mod 71 >
# 642 mod 781 = < 4 mod 11 , 3 mod 71 >
# 643 mod 781 = < 5 mod 11 , 4 mod 71 >
# 644 mod 781 = < 6 mod 11 , 5 mod 71 >
# 645 mod 781 = < 7 mod 11 , 6 mod 71 >
# 646 mod 781 = < 8 mod 11 , 7 mod 71 >
# 647 mod 781 = < 9 mod 11 , 8 mod 71 >
# 648 mod 781 = < 10 mod 11 , 9 mod 71 >
# 649 mod 781 = < 0 mod 11 , 10 mod 71 >   a zero tells us it's NOT relatively prime
# 650 mod 781 = < 1 mod 11 , 11 mod 71 >
# 651 mod 781 = < 2 mod 11 , 12 mod 71 >
# 652 mod 781 = < 3 mod 11 , 13 mod 71 >
# 653 mod 781 = < 4 mod 11 , 14 mod 71 >
# 654 mod 781 = < 5 mod 11 , 15 mod 71 >
# 655 mod 781 = < 6 mod 11 , 16 mod 71 >
# 656 mod 781 = < 7 mod 11 , 17 mod 71 >
# 657 mod 781 = < 8 mod 11 , 18 mod 71 >
# 658 mod 781 = < 9 mod 11 , 19 mod 71 >
# 659 mod 781 = < 10 mod 11 , 20 mod 71 >
# 660 mod 781 = < 0 mod 11 , 21 mod 71 >   a zero tells us it's NOT relatively prime
# 661 mod 781 = < 1 mod 11 , 22 mod 71 >
# 662 mod 781 = < 2 mod 11 , 23 mod 71 >
# 663 mod 781 = < 3 mod 11 , 24 mod 71 >
# 664 mod 781 = < 4 mod 11 , 25 mod 71 >
# 665 mod 781 = < 5 mod 11 , 26 mod 71 >
# 666 mod 781 = < 6 mod 11 , 27 mod 71 >
# 667 mod 781 = < 7 mod 11 , 28 mod 71 >
# 668 mod 781 = < 8 mod 11 , 29 mod 71 >
# 669 mod 781 = < 9 mod 11 , 30 mod 71 >
# 670 mod 781 = < 10 mod 11 , 31 mod 71 >
# 671 mod 781 = < 0 mod 11 , 32 mod 71 >   a zero tells us it's NOT relatively prime
# 672 mod 781 = < 1 mod 11 , 33 mod 71 >
# 673 mod 781 = < 2 mod 11 , 34 mod 71 >
# 674 mod 781 = < 3 mod 11 , 35 mod 71 >
# 675 mod 781 = < 4 mod 11 , 36 mod 71 >
# 676 mod 781 = < 5 mod 11 , 37 mod 71 >
# 677 mod 781 = < 6 mod 11 , 38 mod 71 >
# 678 mod 781 = < 7 mod 11 , 39 mod 71 >
# 679 mod 781 = < 8 mod 11 , 40 mod 71 >
# 680 mod 781 = < 9 mod 11 , 41 mod 71 >
# 681 mod 781 = < 10 mod 11 , 42 mod 71 >
# 682 mod 781 = < 0 mod 11 , 43 mod 71 >   a zero tells us it's NOT relatively prime
# 683 mod 781 = < 1 mod 11 , 44 mod 71 >
# 684 mod 781 = < 2 mod 11 , 45 mod 71 >
# 685 mod 781 = < 3 mod 11 , 46 mod 71 >
# 686 mod 781 = < 4 mod 11 , 47 mod 71 >
# 687 mod 781 = < 5 mod 11 , 48 mod 71 >
# 688 mod 781 = < 6 mod 11 , 49 mod 71 >
# 689 mod 781 = < 7 mod 11 , 50 mod 71 >
# 690 mod 781 = < 8 mod 11 , 51 mod 71 >
# 691 mod 781 = < 9 mod 11 , 52 mod 71 >
# 692 mod 781 = < 10 mod 11 , 53 mod 71 >
# 693 mod 781 = < 0 mod 11 , 54 mod 71 >   a zero tells us it's NOT relatively prime
# 694 mod 781 = < 1 mod 11 , 55 mod 71 >
# 695 mod 781 = < 2 mod 11 , 56 mod 71 >
# 696 mod 781 = < 3 mod 11 , 57 mod 71 >
# 697 mod 781 = < 4 mod 11 , 58 mod 71 >
# 698 mod 781 = < 5 mod 11 , 59 mod 71 >
# 699 mod 781 = < 6 mod 11 , 60 mod 71 >
# 700 mod 781 = < 7 mod 11 , 61 mod 71 >
# 701 mod 781 = < 8 mod 11 , 62 mod 71 >
# 702 mod 781 = < 9 mod 11 , 63 mod 71 >
# 703 mod 781 = < 10 mod 11 , 64 mod 71 >
# 704 mod 781 = < 0 mod 11 , 65 mod 71 >   a zero tells us it's NOT relatively prime
# 705 mod 781 = < 1 mod 11 , 66 mod 71 >
# 706 mod 781 = < 2 mod 11 , 67 mod 71 >
# 707 mod 781 = < 3 mod 11 , 68 mod 71 >
# 708 mod 781 = < 4 mod 11 , 69 mod 71 >
# 709 mod 781 = < 5 mod 11 , 70 mod 71 >
# 710 mod 781 = < 6 mod 11 , 0 mod 71 >   a zero tells us it's NOT relatively prime
# 711 mod 781 = < 7 mod 11 , 1 mod 71 >
# 712 mod 781 = < 8 mod 11 , 2 mod 71 >
# 713 mod 781 = < 9 mod 11 , 3 mod 71 >
# 714 mod 781 = < 10 mod 11 , 4 mod 71 >
# 715 mod 781 = < 0 mod 11 , 5 mod 71 >   a zero tells us it's NOT relatively prime
# 716 mod 781 = < 1 mod 11 , 6 mod 71 >
# 717 mod 781 = < 2 mod 11 , 7 mod 71 >
# 718 mod 781 = < 3 mod 11 , 8 mod 71 >
# 719 mod 781 = < 4 mod 11 , 9 mod 71 >
# 720 mod 781 = < 5 mod 11 , 10 mod 71 >
# 721 mod 781 = < 6 mod 11 , 11 mod 71 >
# 722 mod 781 = < 7 mod 11 , 12 mod 71 >
# 723 mod 781 = < 8 mod 11 , 13 mod 71 >
# 724 mod 781 = < 9 mod 11 , 14 mod 71 >
# 725 mod 781 = < 10 mod 11 , 15 mod 71 >
# 726 mod 781 = < 0 mod 11 , 16 mod 71 >   a zero tells us it's NOT relatively prime
# 727 mod 781 = < 1 mod 11 , 17 mod 71 >
# 728 mod 781 = < 2 mod 11 , 18 mod 71 >
# 729 mod 781 = < 3 mod 11 , 19 mod 71 >
# 730 mod 781 = < 4 mod 11 , 20 mod 71 >
# 731 mod 781 = < 5 mod 11 , 21 mod 71 >
# 732 mod 781 = < 6 mod 11 , 22 mod 71 >
# 733 mod 781 = < 7 mod 11 , 23 mod 71 >
# 734 mod 781 = < 8 mod 11 , 24 mod 71 >
# 735 mod 781 = < 9 mod 11 , 25 mod 71 >
# 736 mod 781 = < 10 mod 11 , 26 mod 71 >
# 737 mod 781 = < 0 mod 11 , 27 mod 71 >   a zero tells us it's NOT relatively prime
# 738 mod 781 = < 1 mod 11 , 28 mod 71 >
# 739 mod 781 = < 2 mod 11 , 29 mod 71 >
# 740 mod 781 = < 3 mod 11 , 30 mod 71 >
# 741 mod 781 = < 4 mod 11 , 31 mod 71 >
# 742 mod 781 = < 5 mod 11 , 32 mod 71 >
# 743 mod 781 = < 6 mod 11 , 33 mod 71 >
# 744 mod 781 = < 7 mod 11 , 34 mod 71 >
# 745 mod 781 = < 8 mod 11 , 35 mod 71 >
# 746 mod 781 = < 9 mod 11 , 36 mod 71 >
# 747 mod 781 = < 10 mod 11 , 37 mod 71 >
# 748 mod 781 = < 0 mod 11 , 38 mod 71 >   a zero tells us it's NOT relatively prime
# 749 mod 781 = < 1 mod 11 , 39 mod 71 >
# 750 mod 781 = < 2 mod 11 , 40 mod 71 >
# 751 mod 781 = < 3 mod 11 , 41 mod 71 >
# 752 mod 781 = < 4 mod 11 , 42 mod 71 >
# 753 mod 781 = < 5 mod 11 , 43 mod 71 >
# 754 mod 781 = < 6 mod 11 , 44 mod 71 >
# 755 mod 781 = < 7 mod 11 , 45 mod 71 >
# 756 mod 781 = < 8 mod 11 , 46 mod 71 >
# 757 mod 781 = < 9 mod 11 , 47 mod 71 >
# 758 mod 781 = < 10 mod 11 , 48 mod 71 >
# 759 mod 781 = < 0 mod 11 , 49 mod 71 >   a zero tells us it's NOT relatively prime
# 760 mod 781 = < 1 mod 11 , 50 mod 71 >
# 761 mod 781 = < 2 mod 11 , 51 mod 71 >
# 762 mod 781 = < 3 mod 11 , 52 mod 71 >
# 763 mod 781 = < 4 mod 11 , 53 mod 71 >
# 764 mod 781 = < 5 mod 11 , 54 mod 71 >
# 765 mod 781 = < 6 mod 11 , 55 mod 71 >
# 766 mod 781 = < 7 mod 11 , 56 mod 71 >
# 767 mod 781 = < 8 mod 11 , 57 mod 71 >
# 768 mod 781 = < 9 mod 11 , 58 mod 71 >
# 769 mod 781 = < 10 mod 11 , 59 mod 71 >
# 770 mod 781 = < 0 mod 11 , 60 mod 71 >   a zero tells us it's NOT relatively prime
# 771 mod 781 = < 1 mod 11 , 61 mod 71 >
# 772 mod 781 = < 2 mod 11 , 62 mod 71 >
# 773 mod 781 = < 3 mod 11 , 63 mod 71 >
# 774 mod 781 = < 4 mod 11 , 64 mod 71 >
# 775 mod 781 = < 5 mod 11 , 65 mod 71 >
# 776 mod 781 = < 6 mod 11 , 66 mod 71 >
# 777 mod 781 = < 7 mod 11 , 67 mod 71 >
# 778 mod 781 = < 8 mod 11 , 68 mod 71 >
# 779 mod 781 = < 9 mod 11 , 69 mod 71 >
# 780 mod 781 = < 10 mod 11 , 70 mod 71 >

# %% [markdown]
# The above are showing 1 period with respect to n.
#
# Take a look at the residues for each of p and q and see their periods.

# %% [markdown]
# ### Each row in the Chinese Remainder Theorem CRT Notation is a System of Linear Congruences
#
# So far, we have discussed using the CRT to solve a system of linear congruences.  We also discussed the CRT Notation.  Now we tie them together by demonstrating that 1 line in CRT Notation is a system of linear congruences which can be solved to resolve the CRT Notation.

# %%
# 7 mod 15 = < 1 mod 3 , 2 mod 5 > 

# is equivalent to: 

# x congruent 1 (mod 3)
# x congruent 2 (mod 5)

# looking at the CRT line at the top, the answer should be 7

my_solve_crt([(1,3),(2,5)])
# Out:
# Congruences:
#     x congruent 1 (mod 3)
#     x congruent 2 (mod 5)
#
# start value: 2
# stop value : 15
# (inclusive)
#
#      2 is NOT a solution
#      3 is NOT a solution
#      4 is NOT a solution
#      5 is NOT a solution
#      6 is NOT a solution
#
# *** 7 is the solution ***
#     7 (mod 3) = 1
#     7 (mod 5) = 2

# %%
# 74 mod 77 = < 4 mod 7 , 8 mod 11 > 

# is equivalent to: 

# x congruent 4 (mod 7)
# x congruent 8 (mod 11)

# looking at the CRT line at the top, the answer should be 74

my_solve_crt([(4,7),(8,11)])
# Out:
# Congruences:
#     x congruent 4 (mod 7)
#     x congruent 8 (mod 11)
#
# start value: 8
# stop value : 77
# (inclusive)
#
#      8 is NOT a solution
#      9 is NOT a solution
#      10 is NOT a solution
#      11 is NOT a solution
#      12 is NOT a solution
#      13 is NOT a solution
#      14 is NOT a solution
#      15 is NOT a solution
#      16 is NOT a solution
#      17 is NOT a solution
#      18 is NOT a solution
#      19 is NOT a solution
#      20 is NOT a solution
#      21 is NOT a solution
#      22 is NOT a solution
#      23 is NOT a solution
#      24 is NOT a solution
#      25 is NOT a solution
#      26 is NOT a solution
#      27 is NOT a solution
#      28 is NOT a solution
#      29 is NOT a solution
#      30 is NOT a solution
#      31 is NOT a solution
#      32 is NOT a solution
#      33 is NOT a solution
#      34 is NOT a solution
#      35 is NOT a solution
#      36 is NOT a solution
#      37 is NOT a solution
#      38 is NOT a solution
#      39 is NOT a solution
#      40 is NOT a solution
#      41 is NOT a solution
#      42 is NOT a solution
#      43 is NOT a solution
#      44 is NOT a solution
#      45 is NOT a solution
#      46 is NOT a solution
#      47 is NOT a solution
#      48 is NOT a solution
#      49 is NOT a solution
#      50 is NOT a solution
#      51 is NOT a solution
#      52 is NOT a solution
#      53 is NOT a solution
#      54 is NOT a solution
#      55 is NOT a solution
#      56 is NOT a solution
#      57 is NOT a solution
#      58 is NOT a solution
#      59 is NOT a solution
#      60 is NOT a solution
#      61 is NOT a solution
#      62 is NOT a solution
#      63 is NOT a solution
#      64 is NOT a solution
#      65 is NOT a solution
#      66 is NOT a solution
#      67 is NOT a solution
#      68 is NOT a solution
#      69 is NOT a solution
#      70 is NOT a solution
#      71 is NOT a solution
#      72 is NOT a solution
#      73 is NOT a solution
#
# *** 74 is the solution ***
#     74 (mod 7) = 4
#     74 (mod 11) = 8
